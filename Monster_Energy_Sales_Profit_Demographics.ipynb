# %%
# %% [markdown]
# # Monster Energy Sales, Profit Margins & Demographics Dataset
# 
# This notebook collects publicly available sales and profitability metrics from Monster Beverage Corporation
# and basic consumer demographic insights for the Monster Energy drink brand.

# %%
# --- 1) IMPORT LIBRARIES ---
import pandas as pd

# %%
# --- 2) CREATE SALES & PROFIT DATA TABLE ---

# We compile key annual and quarterly performance metrics:
data_sales = {
    'Period': [
        '2024 Annual Revenue',
        '2023 Annual Revenue',
        'Q4 2024 Net Sales (Monster Energy Segment)',
        'Q4 2024 Gross Profit Margin'
    ],
    'Value': [
        7.493,   # $Billion
        7.140,   # $Billion
        1.67,    # $Billion from Monster Energy Drinks
        55.3     # Percentage (%)
    ],
    'Unit': [
        'USD Billion',
        'USD Billion',
        'USD Billion',
        'Percent'
    ],
    'Source': [
        'Monster Beverage 2024 Annual Report',
        'Monster Beverage 2024 Annual Report',
        'Monster Beverage Q4 2024 Results',
        'Monster Beverage Q4 2024 Results'
    ]
}

df_sales = pd.DataFrame(data_sales)
df_sales

# %% [markdown]
# 📈 Summary:
# - **2024 Annual Revenue:** ~$7.49B.  
# - **2023 Annual Revenue:** ~$7.14B.  
# - **Q4 2024 Monster Energy Segment Sales:** ~$1.67B.  
# - **Q4 2024 Gross Profit Margin:** ~55.3%.  
#
# (Values aggregated from periodic company filings.) :contentReference[oaicite:1]{index=1}

# %%
# --- 3) ADD DEMOGRAPHICS DATA ---

data_demographics = {
    'Attribute': [
        'Core Consumer Gender',
        'Core Age Group',
        'Revenue Contribution (Core Demo)'
    ],
    'Value': [
        'Male',
        '18-34 Years Old',
        '60%'  # Approx. share by this demographic
    ],
    'Source': [
        'Monster Energy Consumer Profile',
        'Monster Energy Consumer Profile',
        'Monster Energy Consumer Profile'
    ]
}

df_demo = pd.DataFrame(data_demographics)
df_demo

# %% [markdown]
# 🔍 Consumer Profile Highlights:
# - Core Monster Energy drink consumers are predominantly **male**.  
# - The most active age range is **18-34 years** old.  
# - This demographic contributes an estimated **~60% of revenue**.  
# (Data from aggregated consumer trend reports.) :contentReference[oaicite:2]{index=2}

# %%
# --- 4) EXPORT DATA TO CSV ---

df_sales.to_csv('monster_sales_data.csv', index=False)
df_demo.to_csv('monster_demographics_data.csv', index=False)

print("CSV files written: monster_sales_data.csv, monster_demographics_data.csv")

# %% [markdown]
# ## Next Steps (Suggestions)
# - Link this dataset with **market share** and **regional revenue split**.
# - Add **segmented sales figures** (e.g., by sub-brand, product SKU).
# - Use visualization libraries (e.g., `matplotlib`) to create trend charts.
# Out:
# CSV files written: monster_sales_data.csv, monster_demographics_data.csv
